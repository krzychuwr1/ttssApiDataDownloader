# %%
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from time import time
from datetime import datetime, timedelta

plt.rcParams["figure.figsize"] = (15,5)

# %%
root_dir = '/home/karol/ed/data'

tram_delays = []

time_dir_names = os.listdir(root_dir)

print('Times to process = ', len(time_dir_names))
# Out:
# Times to process =  3335

# %%
idx = 0
for time_dir_name in time_dir_names:
    dir_dt = datetime(1, 1, 1) + timedelta(microseconds=int(time_dir_name.split('_')[-1])/10)
    idx = idx + 1
    if idx % (len(time_dir_names)/21) == 1:
        print(100 * idx / len(time_dir_names), '%')
    try:
        stopPassages_path = os.path.join(root_dir, time_dir_name, 'stopPassages')
        stopPassages_file_names = os.listdir(stopPassages_path)
        for file_name in stopPassages_file_names:
            try:
                file_path = os.path.join(stopPassages_path, file_name)
                with open(file_path, encoding="utf8") as f:
                    file_content = f.read()
                    stopPassage_dict = json.loads(file_content)
                    stopName = stopPassage_dict['stopName']
                    stoppings = [s for s in stopPassage_dict['actual'] if s['status'] == 'STOPPING']
                    for stopping in stoppings:
                        try:
                            actual_dt = datetime.strptime(stopping['actualTime'], '%H:%M')
                            planned_dt = datetime.strptime(stopping['plannedTime'], '%H:%M')
                            tram_delays.append({'vehicleId': stopping['vehicleId'],
                                                'direction': stopping['direction'],
                                                'patternText': stopping['patternText'],
                                                'tripId': stopping['tripId'],
                                                'stopName': stopName,
                                                'delay': int((actual_dt - planned_dt).seconds / 60),
                                                'time': actual_dt.time(),
                                                'day_of_week': dir_dt.weekday()})
                        except Exception as e:
                            print(e)
            except Exception as e:
                print(e)
    except Exception as e:
        print(e)
# Out:
# 0.029985007496251874 %
# 20.02998500749625 %
# 40.02998500749625 %
# 60.02998500749625 %
# 80.02998500749625 %

# %%
len(tram_delays)
# Out:
# 168065

# %%
tram_delays_df = pd.DataFrame(tram_delays, columns=['vehicleId', 'direction', 'patternText', 'tripId', 'stopName', 'time', 'day_of_week', 'delay', ])

# %%
tram_delays_df
# Out:
#                   vehicleId          direction patternText  \
# 0       6352185295672181141  Czerwone Maki P+R          17
# 1       6352185295672181735  Nowy Bieżanów P+R          73
# 2       6352185295672181187         Wzgórza K.           5
# 3       6352185295672181162         Wzgórza K.           1
# 4       6352185295672181373       Mały Płaszów          78
# 5       6352185295672180856         Os.Piastów          52
# 6       6352185295672181362         Łagiewniki          78
# 7       6352185295672181652         Wzgórza K.          73
# 8       6352185295672181189    Krowodrza Górka           5
# 9       6352185295672181167         Wzgórza K.           1
# 10      6352185295672180893  Nowy Bieżanów P+R          73
# 11      6352185295672181143    Krowodrza Górka           5
# 12      6352185295672181641  Nowy Bieżanów P+R          73
# 13      6352185295672180899         Łagiewniki          22
# 14      6352185295672181385  Nowy Bieżanów P+R           3
# 15      6352185295672181537  Czerwone Maki P+R          18
# 16      6352185295672181665         Os.Piastów          52
# 17      6352185295672181654      Kurdwanów P+R          50
#                        19           Dworzec Tow.           138
#                                     Łagiewniki              92
#                        24           Cichy Kącik            136
#                                     Kurdwanów P+R          106
#                        3            Dworzec Tow.            21
#                                     Krowodrza Górka        128
#                                     Nowy Bieżanów P+R      170
# Length: 1138, dtype: int64

# %%
# tram_delays_df.to_csv('tram_delays.csv')

# %%
tram_delays_df = pd.read_csv('tram_delays_day.csv')
tram_delays_df['time'] =  pd.to_datetime(tram_delays_df['time'], format='%H:%M:%S')
tram_delays_df = tram_delays_df.sort_values(by=['time'])

# %%
tram_delays_df.head(10)
# Out:
#         Unnamed: 0            vehicleId            direction  patternText  \
# 167682      167682  6352185295672181371    Nowy Bieżanów P+R            3
# 167681      167681  6352185295672181553        Kurdwanów P+R           50
# 119974      119974  6352185295672180876             Kombinat           22
# 119975      119975  6352185295672181371    Nowy Bieżanów P+R            3
# 79775        79775  6352185295672181671  Zajezdnia Nowa Huta           73
# 152275      152275  6352185295672180876             Kombinat           22
# 158748      158748  6352185295672181671  Zajezdnia Nowa Huta           73
# 154531      154531  6352185295672180876             Kombinat           22
# 124059      124059  6352185295672181671  Zajezdnia Nowa Huta           73
# 88311        88311  6352185295672181671  Zajezdnia Nowa Huta           73
#
#                      tripId           stopName                time  \
# 167682  6351558574044460055             Teligi 1900-01-01 00:00:00
# 167681  6351558574044963863             Witosa 1900-01-01 00:00:00
# 119974  6351558574044836883       Hala Targowa 1900-01-01 00:01:00
# 119975  6351558574044460055      Nowy Prokocim 1900-01-01 00:01:00
# 79775   6351558574045180941  Stella-Sawickiego 1900-01-01 00:05:00
# 152275  6351558574044836883      Teatr Variété 1900-01-01 00:05:00
# 158748  6351558574045180941            Czyżyny 1900-01-01 00:06:00
# 154531  6351558574044836883        Ofiar Dąbia 1900-01-01 00:08:00
# 124059  6351558574045180941   Rondo Czyżyńskie 1900-01-01 00:09:00
# 88311   6351558574045180941        Os.Kolorowe 1900-01-01 00:10:00
#
#         day_of_week  delay
# 167682            2      1
# 167681            2      1
# 119974            2      0
# 119975            2      1
# 79775             2      0
# 152275            2      0
# 158748            2      0
# 154531            2      0
# 124059            2      0
# 88311             2      0

# %%
grouped_tram_delays = tram_delays_df.groupby(['stopName', 'patternText', 'direction'])

# %%
result = [g[1] for g in list(grouped_tram_delays)[:1]][0]

# %%
_times = list(sorted(result['time'].values))
print('Times from %s to %s' % (_times[0], _times[-1]))
# Out:
# Times from 1900-01-01T04:47:00.000000000 to 1900-01-01T22:29:00.000000000

# %%
counter = 0
for key, grp in grouped_tram_delays:
    if len(grp['time'].values) > 50:
        grp['rolling_mean_delay'] = grp['delay'].rolling(10).mean()
        fig, ax = plt.subplots(1)
        grp.plot(ax=ax, style='.-', x='time', y='rolling_mean_delay', color='b', label=key)
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
        plt.show()
        counter = counter + 1;
        if(counter > 20):
            break
# Out:
# /home/karol/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
